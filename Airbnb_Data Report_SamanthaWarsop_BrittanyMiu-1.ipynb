# %% [markdown]
# ## Final Proposal:  Airbnb New York City Pricing Dynamics

# %% [markdown]
# ###### *Principal Investigators : Samantha Warsop & Brittany Miu*
# ###### Email: sw3469@nyu.edu bm2352@nyu.edu

# %% [markdown]
# This project will explore how pricing differs across Airbnbs and the influences it has on demand. We will also explore the seasonal pattern of airbnb prices in New York and the effects it has on travel. As an example, in New York City, Airbnb prices across different neighbourhood groups such as Manhattan, Brooklyn, Queens, Staten Island, and the Bronx might differ. We can look at how pricing is varies across these different neighbourhood groups in terms of the number of the listings available and property type available.
#
# The key element of the project is the use of Airbnb’s data, providing access to measures such as prices, number of listings, property type, etc.  in New York. Detailed of this dataset are described below in the data report.
#
# There will be three different sections in this project:
# ##### 1. Basic Data Analysis
#
# This section will have different summary statistics describing the number of listings and property type in each neighbourhood group.
# ##### 2. Pricing Effect on Demand for New York City Airbnbs
#
# This section will explore how prices differ across different neighbourhood groups and discover what factors prices are dependent on. We will have visualizations such as a map to indicate where entire apartments/homes are most prevalent. There will be a bar chart illustrating the average prices in each neighbourhood. By analyzing the number of listings and prices per neighbourhood, we can find out which neighbourhood is the most optimal.
# ##### 3. Seasonal Pattern of Prices
#
# The last will explore how prices vary across different seasons. We plan to have visualizations showing how prices change over the year and provide explanations as to why. For example, airbnb prices during the holidays might be more expensive than during non-holidays.

# %% [markdown]
# ### Data Report

# %% [markdown]
# ##### Overview:
# The data behind our project comes from [insideairbnb](http://insideairbnb.com/get-the-data.html) . Their [New York city data](http://insideairbnb.com/new-york-city/) provides access to information on room types, availability, activity, as well as listings per host.
#
# ##### Important Variables:
# The key series that we must retrive is within insideairbnb's data on [New York city data](http://insideairbnb.com/new-york-city/).
# This data provides the airbnb locations, as well as pricing, which will allow us to determine answers to both questions 1 and 2.
# This data combined with utalizing datetime and holiday functions will allow us to analyze Airbnb's seasonal pattern of prices.
#
#
# ##### Access:
# We will use insideairbnb to download and acess the data. Below we will demonstrate that we have the ability to access the data.
#
#
# ##### Requisite Packages:
# Below we will bring in the packages we need:

# %%
import pandas as pd
import numpy as np #numerical analysis 
import matplotlib.pyplot as plt #plotting
import geopandas as gpd
import os
import time 
from datetime import date
import datetime
import holidays
import calendar
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes
from mpl_toolkits.axes_grid1.inset_locator import mark_inset

# %%
file= "/Users/SamanthaWarsop 1/Airbnb New York/listings.csv"

# %%
listings = pd.read_csv(file)
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (43,95) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
listings.head()
# Out:
#          id                            listing_url       scrape_id  \
# 0   1742654   https://www.airbnb.com/rooms/1742654  20190503153024
# 1  23502842  https://www.airbnb.com/rooms/23502842  20190503153024
# 2  15984984  https://www.airbnb.com/rooms/15984984  20190503153024
# 3  13820083  https://www.airbnb.com/rooms/13820083  20190503153024
# 4   6170979   https://www.airbnb.com/rooms/6170979  20190503153024
#
#   last_scraped                                              name  \
# 0   2019-05-04               High Floor apt.near Columbus Circle
# 1   2019-05-04                          Cozy East Village studio
# 2   2019-05-04                         Great Location by Subway!
# 3   2019-05-04  Beautiful Cozy Garden Apt- Historic Clinton Hill
# 4   2019-05-04                Cozy 1 Bedroom apartment fitting 4
#
#                                              summary  \
# 0  Deep in the heart of Manhattan, this Little To...
# 1  Studio apartment on a quiet street.  Great nat...
# 2  I have a very spacious apartment right next to...
# 3  Non Smoking. Close to Barclays Center, Peaches...
# 4  The Apartment is in a safe environment next to...
#
#                                                space  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  The space is on the first floor local train: A...
# 4                                                NaN
#
#                                          description experiences_offered  \
# 0  Deep in the heart of Manhattan, this Little To...                none
# 1  Studio apartment on a quiet street.  Great nat...                none
# 2  I have a very spacious apartment right next to...                none
# 3  Non Smoking. Close to Barclays Center, Peaches...                none
# 4  The Apartment is in a safe environment next to...                none
#
#                                neighborhood_overview        ...          \
# 0  This neighborhood is amazing. The best in nigh...        ...
# 1  Very quiet street but restaurants /cafes /wine...        ...
# 2                                                NaN        ...
# 3  Clinton hill is regentrified and often referre...        ...
# 4                                                NaN        ...
#
#   instant_bookable is_business_travel_ready          cancellation_policy  \
# 0                f                        f  strict_14_with_grace_period
# 1                f                        f  strict_14_with_grace_period
# 2                t                        f  strict_14_with_grace_period
# 3                t                        f                     moderate
# 4                t                        f                     flexible
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             t                                t
# 1                             f                                f
# 2                             f                                f
# 3                             f                                f
# 4                             f                                f
#
#    calculated_host_listings_count  \
# 0                               1
# 1                               1
# 2                               1
# 3                               2
# 4                               1
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            1
# 1                                            1
# 2                                            1
# 3                                            2
# 4                                            1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               1.87
# 1                                            0               0.66
# 2                                            0               1.24
# 3                                            0               0.27
# 4                                            0               2.63
#
# [5 rows x 106 columns]

# %% [markdown]
# #### Then we will clean up the data a bit by replacing all the NaN with 0, converting the price type to a floating number, and excluding the listing with 0 for price, bedrooms, accommodations, etc.

# %%
#replacing Nan with 0
listings.fillna(0, inplace = True)

#Getting rid of $ signs and converting price to float
listings['price'] = listings['price'].str.replace('[^\d\.]', '').astype(float)

#Excluding listings with 0 for price, bedrooms, accomodations, etc. 
listings = listings[listings.bathrooms >0]
listings = listings[listings.bedrooms > 0]
listings = listings[listings.beds > 0]
listings = listings[listings.price  > 0]
listings = listings[listings.review_scores_rating  > 0]
listings = listings[listings.reviews_per_month > 0]
listings = listings[listings.accommodates  > 0]

listings.head()
# Out:
#          id                            listing_url       scrape_id  \
# 0   1742654   https://www.airbnb.com/rooms/1742654  20190503153024
# 2  15984984  https://www.airbnb.com/rooms/15984984  20190503153024
# 3  13820083  https://www.airbnb.com/rooms/13820083  20190503153024
# 4   6170979   https://www.airbnb.com/rooms/6170979  20190503153024
# 5  27283214  https://www.airbnb.com/rooms/27283214  20190503153024
#
#   last_scraped                                              name  \
# 0   2019-05-04               High Floor apt.near Columbus Circle
# 2   2019-05-04                         Great Location by Subway!
# 3   2019-05-04  Beautiful Cozy Garden Apt- Historic Clinton Hill
# 4   2019-05-04                Cozy 1 Bedroom apartment fitting 4
# 5   2019-05-04                 Room in Luxury Building - Midtown
#
#                                              summary  \
# 0  Deep in the heart of Manhattan, this Little To...
# 2  I have a very spacious apartment right next to...
# 3  Non Smoking. Close to Barclays Center, Peaches...
# 4  The Apartment is in a safe environment next to...
# 5  Fabulous Room in the heart of NY!  The buildin...
#
#                                                space  \
# 0                                                  0
# 2                                                  0
# 3  The space is on the first floor local train: A...
# 4                                                  0
# 5  Chambre dans le cœur de NY. Située a 2 mins de...
#
#                                          description experiences_offered  \
# 0  Deep in the heart of Manhattan, this Little To...                none
# 2  I have a very spacious apartment right next to...                none
# 3  Non Smoking. Close to Barclays Center, Peaches...                none
# 4  The Apartment is in a safe environment next to...                none
# 5  Fabulous Room in the heart of NY!  The buildin...                none
#
#                                neighborhood_overview        ...          \
# 0  This neighborhood is amazing. The best in nigh...        ...
# 2                                                  0        ...
# 3  Clinton hill is regentrified and often referre...        ...
# 4                                                  0        ...
# 5                                                  0        ...
#
#   instant_bookable is_business_travel_ready          cancellation_policy  \
# 0                f                        f  strict_14_with_grace_period
# 2                t                        f  strict_14_with_grace_period
# 3                t                        f                     moderate
# 4                t                        f                     flexible
# 5                f                        f  strict_14_with_grace_period
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             t                                t
# 2                             f                                f
# 3                             f                                f
# 4                             f                                f
# 5                             f                                f
#
#    calculated_host_listings_count  \
# 0                               1
# 2                               1
# 3                               2
# 4                               1
# 5                               1
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            1
# 2                                            1
# 3                                            2
# 4                                            1
# 5                                            0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 2                                            0
# 3                                            0
# 4                                            0
# 5                                            1
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               1.87
# 2                                            0               1.24
# 3                                            0               0.27
# 4                                            0               2.63
# 5                                            0               0.32
#
# [5 rows x 106 columns]

# %% [markdown]
# ##### Now we are going to delete the unecessary columns

# %%
listings.drop(['listing_url', 'scrape_id', 'last_scraped', 'name', 'summary', 'space', 'description', 'neighborhood_overview', 'cancellation_policy', 'notes', 'transit', 'access', 'interaction', 'house_rules', 'thumbnail_url', 'medium_url', 'picture_url', 'xl_picture_url', 'host_url', 'host_name', 'host_since', 'host_location', 'host_about', 'host_response_time', 'host_response_rate', 'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood', 'host_listings_count', 'host_total_listings_count', 'host_verifications', 'host_has_profile_pic', 'host_identity_verified', 'amenities', 'square_feet', 'minimum_minimum_nights', 'maximum_minimum_nights', 'minimum_maximum_nights', 'maximum_maximum_nights', 'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 'calendar_updated', 'calendar_last_scraped', 'first_review', 'last_review', 'license', 'jurisdiction_names'], axis=1, inplace = True)

# %%
listings.drop(['calculated_host_listings_count_shared_rooms', 'calculated_host_listings_count_private_rooms', 'calculated_host_listings_count_entire_homes', 'calculated_host_listings_count', 'security_deposit', 'cleaning_fee', 'bed_type'], axis=1, inplace=True)

# %%
listings.head()
# Out:
#          id experiences_offered   host_id  host_acceptance_rate  \
# 0   1742654                none   9173924                   0.0
# 2  15984984                none   9737900                   0.0
# 3  13820083                none  31829334                   0.0
# 4   6170979                none  31104121                   0.0
# 5  27283214                none   3508466                   0.0
#
#   host_is_superhost                       street   neighbourhood  \
# 0                 t  New York, NY, United States  Hell's Kitchen
# 2                 t  Brooklyn, NY, United States        Brooklyn
# 3                 f  Brooklyn, NY, United States        Brooklyn
# 4                 f  Brooklyn, NY, United States        Brooklyn
# 5                 f  New York, NY, United States       Manhattan
#
#   neighbourhood_cleansed neighbourhood_group_cleansed      city  \
# 0         Hell's Kitchen                    Manhattan  New York
# 2           Clinton Hill                     Brooklyn  Brooklyn
# 3           Clinton Hill                     Brooklyn  Brooklyn
# 4           Clinton Hill                     Brooklyn  Brooklyn
# 5         Hell's Kitchen                    Manhattan  New York
#
#          ...        review_scores_checkin review_scores_communication  \
# 0        ...                         10.0                        10.0
# 2        ...                         10.0                        10.0
# 3        ...                         10.0                         9.0
# 4        ...                         10.0                         9.0
# 5        ...                         10.0                        10.0
#
#   review_scores_location review_scores_value requires_license  \
# 0                   10.0                10.0                f
# 2                   10.0                10.0                f
# 3                   10.0                 9.0                f
# 4                    9.0                 9.0                f
# 5                   10.0                10.0                f
#
#   instant_bookable  is_business_travel_ready  require_guest_profile_picture  \
# 0                f                         f                              t
# 2                t                         f                              f
# 3                t                         f                              f
# 4                t                         f                              f
# 5                f                         f                              f
#
#   require_guest_phone_verification reviews_per_month
# 0                                t              1.87
# 2                                f              1.24
# 3                                f              0.27
# 4                                f              2.63
# 5                                f              0.32
#
# [5 rows x 52 columns]

# %%
listings.columns
# Out:
# Index(['id', 'experiences_offered', 'host_id', 'host_acceptance_rate',
#        'host_is_superhost', 'street', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'city',
#        'state', 'zipcode', 'market', 'smart_location', 'country_code',
#        'country', 'latitude', 'longitude', 'is_location_exact',
#        'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms',
#        'beds', 'price', 'weekly_price', 'monthly_price', 'guests_included',
#        'extra_people', 'minimum_nights', 'maximum_nights', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'number_of_reviews', 'number_of_reviews_ltm',
#        'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'requires_license', 'instant_bookable',
#        'is_business_travel_ready', 'require_guest_profile_picture',
#        'require_guest_phone_verification', 'reviews_per_month'],
#       dtype='object')

# %% [markdown]
# ##### Now we will grab the time series data from calendar.csv to evaluate how price changes based on season

# %%
calendar_file = "/Users/SamanthaWarsop 1/Airbnb New York/calendar.csv"

# %%
calendar = pd.read_csv(calendar_file)
calendar.head()
# Out:
#    listing_id        date available   price adjusted_price  minimum_nights  \
# 0       36647  2019-03-07         f  $69.00         $69.00             2.0
# 1       36647  2019-03-08         f  $69.00         $69.00             2.0
# 2       36647  2019-03-09         f  $69.00         $69.00             2.0
# 3       36647  2019-03-10         f  $69.00         $69.00             2.0
# 4       36647  2019-03-11         f  $69.00         $69.00             2.0
#
#    maximum_nights
# 0           730.0
# 1           730.0
# 2           730.0
# 3           730.0
# 4           730.0

# %% [markdown]
# ##### Then I am going to clean up the data a bit by replacing all the NaN with 0, converting the price to a floating number, and separating the date column into day, month, and year.

# %%
#replacing NaN with 0 
calendar.fillna(0, inplace = True)

#converting price to float 
calendar['price'] = calendar['price'].str.replace('[^\d\.]', '').astype(float)

#Excluding listing with 0 for price
calendar = calendar[calendar['price'] >= 0]

#Separating date column into day, month, and year
calendar['Year'],calendar['Month'],calendar['Day']=calendar['date'].str.split('-',2).str

#Deleting column for adjusted price 
calendar.drop(['adjusted_price'], axis=1, inplace=True)

calendar.head()
# Out:
#    listing_id        date available  price  minimum_nights  maximum_nights  \
# 0       36647  2019-03-07         f   69.0             2.0           730.0
# 1       36647  2019-03-08         f   69.0             2.0           730.0
# 2       36647  2019-03-09         f   69.0             2.0           730.0
# 3       36647  2019-03-10         f   69.0             2.0           730.0
# 4       36647  2019-03-11         f   69.0             2.0           730.0
#
#    Year Month Day
# 0  2019    03  07
# 1  2019    03  08
# 2  2019    03  09
# 3  2019    03  10
# 4  2019    03  11

# %% [markdown]
# ##### Here are some summary statistics.

# %%
room_type = listings.groupby('room_type').id.count()

# %%
room_type
# Out:
# room_type
# Entire home/apt    16467
# Private room       16139
# Shared room          737
# Name: id, dtype: int64

# %%
neighborhood_group = listings.groupby('neighbourhood_group_cleansed').id.count()

# %%
neighborhood_group
# Out:
# neighbourhood_group_cleansed
# Bronx              745
# Brooklyn         14555
# Manhattan        13817
# Queens            3969
# Staten Island      257
# Name: id, dtype: int64

# %%
listings[listings.neighbourhood_group_cleansed == "Manhattan"].head(10)
# Out:
#           id experiences_offered    host_id  host_acceptance_rate  \
# 0    1742654                none    9173924                   0.0
# 5   27283214                none    3508466                   0.0
# 7      33014                none     143048                   0.0
# 11    150804                none     726333                   0.0
# 16  32783365                none   25312503                   0.0
# 17   1182844                none    6470443                   0.0
# 18   1151782                none    1002618                   0.0
# 19  19219624                none  134521683                   0.0
# 21  19830008                none  139942077                   0.0
# 24  26518779                none    6072790                   0.0
#
#    host_is_superhost                       street   neighbourhood  \
# 0                  t  New York, NY, United States  Hell's Kitchen
# 5                  f  New York, NY, United States       Manhattan
# 7                  f  New York, NY, United States       Manhattan
# 11                 f  New York, NY, United States       Manhattan
# 16                 f  New York, NY, United States       Manhattan
# 17                 f  New York, NY, United States         Midtown
# 18                 f  New York, NY, United States  Hell's Kitchen
# 19                 f  New York, NY, United States       Manhattan
# 21                 f  New York, NY, United States   Alphabet City
# 24                 f  New York, NY, United States   Alphabet City
#
#    neighbourhood_cleansed neighbourhood_group_cleansed      city  \
# 0          Hell's Kitchen                    Manhattan  New York
# 5          Hell's Kitchen                    Manhattan  New York
# 7            East Village                    Manhattan  New York
# 11        Lower East Side                    Manhattan  New York
# 16           East Village                    Manhattan  New York
# 17         Hell's Kitchen                    Manhattan  New York
# 18         Hell's Kitchen                    Manhattan  New York
# 19           East Village                    Manhattan  New York
# 21           East Village                    Manhattan  New York
# 24           East Village                    Manhattan  New York
#
#           ...        review_scores_checkin review_scores_communication  \
# 0         ...                         10.0                        10.0
# 5         ...                         10.0                        10.0
# 7         ...                          9.0                         9.0
# 11        ...                         10.0                        10.0
# 16        ...                         10.0                        10.0
# 17        ...                         10.0                        10.0
# 18        ...                          9.0                        10.0
# 19        ...                         10.0                        10.0
# 21        ...                         10.0                        10.0
# 24        ...                          8.0                        10.0
#
#    review_scores_location review_scores_value requires_license  \
# 0                    10.0                10.0                f
# 5                    10.0                10.0                f
# 7                     9.0                 9.0                f
# 11                   10.0                10.0                f
# 16                   10.0                10.0                f
# 17                   10.0                 9.0                f
# 18                   10.0                 9.0                f
# 19                   10.0                10.0                f
# 21                   10.0                10.0                f
# 24                    8.0                 8.0                f
#
#    instant_bookable  is_business_travel_ready  require_guest_profile_picture  \
# 0                 f                         f                              t
# 5                 f                         f                              f
# 7                 f                         f                              f
# 11                f                         f                              f
# 16                t                         f                              f
# 17                f                         f                              f
# 18                f                         f                              f
# 19                f                         f                              f
# 21                t                         f                              f
# 24                f                         f                              f
#
#    require_guest_phone_verification reviews_per_month
# 0                                 t              1.87
# 5                                 f              0.32
# 7                                 f              0.27
# 11                                f              0.17
# 16                                f              5.00
# 17                                f              0.54
# 18                                f              0.11
# 19                                f              0.13
# 21                                f              2.90
# 24                                f              0.12
#
# [10 rows x 52 columns]

# %% [markdown]
# ### Summary
# With the listings.csv, we can answer the first and second question that will evaluate the differences in number of listings, property type, etc. to explain the price differences across different neighbourhood groups. With the calendar.csv, we can evaluate the seasonal patterns of prices. With the combined data frame, we can go more indepth of how prices changes over the years based on different neighborhood groups.
#
# We look forward to finding the answers to our questions, and seeing where the data takes us!

# %% [markdown]
# #### Exporting the csv below

# %%
listings.rename(columns={'id':'listing_id'}, inplace=True)

# %%
listings.columns
# Out:
# Index(['listing_id', 'experiences_offered', 'host_id', 'host_acceptance_rate',
#        'host_is_superhost', 'street', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'city',
#        'state', 'zipcode', 'market', 'smart_location', 'country_code',
#        'country', 'latitude', 'longitude', 'is_location_exact',
#        'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms',
#        'beds', 'price', 'weekly_price', 'monthly_price', 'guests_included',
#        'extra_people', 'minimum_nights', 'maximum_nights', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'number_of_reviews', 'number_of_reviews_ltm',
#        'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'requires_license', 'instant_bookable',
#        'is_business_travel_ready', 'require_guest_profile_picture',
#        'require_guest_phone_verification', 'reviews_per_month'],
#       dtype='object')

# %%
listings_calendar = pd.merge(listings, calendar, on='listing_id', how='outer')

# %%
listings_calendar
# Out:
#           listing_id experiences_offered    host_id  host_acceptance_rate  \
# 0            1742654                none  9173924.0                   0.0
# 1            1742654                none  9173924.0                   0.0
# 2            1742654                none  9173924.0                   0.0
# 3            1742654                none  9173924.0                   0.0
# 4            1742654                none  9173924.0                   0.0
# 5            1742654                none  9173924.0                   0.0
# 6            1742654                none  9173924.0                   0.0
# 7            1742654                none  9173924.0                   0.0
# 8            1742654                none  9173924.0                   0.0
# 9            1742654                none  9173924.0                   0.0
# 10           1742654                none  9173924.0                   0.0
# 11           1742654                none  9173924.0                   0.0
# 12           1742654                none  9173924.0                   0.0
# 13           1742654                none  9173924.0                   0.0
# 14           1742654                none  9173924.0                   0.0
# 15           1742654                none  9173924.0                   0.0
# 16           1742654                none  9173924.0                   0.0
# 17           1742654                none  9173924.0                   0.0
# 18           1742654                none  9173924.0                   0.0
# 19           1742654                none  9173924.0                   0.0
# 20           1742654                none  9173924.0                   0.0
# 21           1742654                none  9173924.0                   0.0
# 22           1742654                none  9173924.0                   0.0
# 23           1742654                none  9173924.0                   0.0
# 24           1742654                none  9173924.0                   0.0
# 25           1742654                none  9173924.0                   0.0
# 26           1742654                none  9173924.0                   0.0
# 27           1742654                none  9173924.0                   0.0
# 28           1742654                none  9173924.0                   0.0
# 29           1742654                none  9173924.0                   0.0
# ...              ...                 ...        ...                   ...
# 18160235    32765748                 NaN        NaN                   NaN
# 18160236    32765748                 NaN        NaN                   NaN
# 18160237    32765748                 NaN        NaN                   NaN
# 18160238    32765748                 NaN        NaN                   NaN
# 18160239    32765748                 NaN        NaN                   NaN
# 18160240    32765748                 NaN        NaN                   NaN
# 18160241    32765748                 NaN        NaN                   NaN
# 18160242    32765748                 NaN        NaN                   NaN
# 18160243    32765748                 NaN        NaN                   NaN
# 18160244    32765748                 NaN        NaN                   NaN
# 18160245    32765748                 NaN        NaN                   NaN
# 18160246    32765748                 NaN        NaN                   NaN
# 18160247    32765748                 NaN        NaN                   NaN
# 18160248    32765748                 NaN        NaN                   NaN
# 18160249    32765748                 NaN        NaN                   NaN
# 18160250    32765748                 NaN        NaN                   NaN
# 18160251    32765748                 NaN        NaN                   NaN
# 18160252    32765748                 NaN        NaN                   NaN
# 18160253    32765748                 NaN        NaN                   NaN
# 18160254    32765748                 NaN        NaN                   NaN
# 18160255    32765748                 NaN        NaN                   NaN
# 18160256    32765748                 NaN        NaN                   NaN
# 18160257    32765748                 NaN        NaN                   NaN
# 18160258    32765748                 NaN        NaN                   NaN
# 18160259    32765748                 NaN        NaN                   NaN
# 18160260    32765748                 NaN        NaN                   NaN
# 18160261    32765748                 NaN        NaN                   NaN
# 18160262    32765748                 NaN        NaN                   NaN
# 18160263    32765748                 NaN        NaN                   NaN
# 18160264    32765748                 NaN        NaN                   NaN
#
#          host_is_superhost                       street   neighbourhood  \
# 0                        t  New York, NY, United States  Hell's Kitchen
# 1                        t  New York, NY, United States  Hell's Kitchen
# 2                        t  New York, NY, United States  Hell's Kitchen
# 3                        t  New York, NY, United States  Hell's Kitchen
# 4                        t  New York, NY, United States  Hell's Kitchen
# 5                        t  New York, NY, United States  Hell's Kitchen
# 6                        t  New York, NY, United States  Hell's Kitchen
# 7                        t  New York, NY, United States  Hell's Kitchen
# 8                        t  New York, NY, United States  Hell's Kitchen
# 9                        t  New York, NY, United States  Hell's Kitchen
# 10                       t  New York, NY, United States  Hell's Kitchen
# 11                       t  New York, NY, United States  Hell's Kitchen
# 12                       t  New York, NY, United States  Hell's Kitchen
# 13                       t  New York, NY, United States  Hell's Kitchen
# 14                       t  New York, NY, United States  Hell's Kitchen
# 15                       t  New York, NY, United States  Hell's Kitchen
# 16                       t  New York, NY, United States  Hell's Kitchen
# 17                       t  New York, NY, United States  Hell's Kitchen
# 18                       t  New York, NY, United States  Hell's Kitchen
# 19                       t  New York, NY, United States  Hell's Kitchen
# 20                       t  New York, NY, United States  Hell's Kitchen
# 21                       t  New York, NY, United States  Hell's Kitchen
# 22                       t  New York, NY, United States  Hell's Kitchen
# 23                       t  New York, NY, United States  Hell's Kitchen
# 24                       t  New York, NY, United States  Hell's Kitchen
# 25                       t  New York, NY, United States  Hell's Kitchen
# 26                       t  New York, NY, United States  Hell's Kitchen
# 27                       t  New York, NY, United States  Hell's Kitchen
# 28                       t  New York, NY, United States  Hell's Kitchen
# 29                       t  New York, NY, United States  Hell's Kitchen
# ...                    ...                          ...             ...
# 18160235               NaN                          NaN             NaN
# 18160236               NaN                          NaN             NaN
# 18160237               NaN                          NaN             NaN
# 18160238               NaN                          NaN             NaN
# 18160239               NaN                          NaN             NaN
# 18160240               NaN                          NaN             NaN
# 18160241               NaN                          NaN             NaN
# 18160242               NaN                          NaN             NaN
# 18160243               NaN                          NaN             NaN
# 18160244               NaN                          NaN             NaN
# 18160245               NaN                          NaN             NaN
# 18160246               NaN                          NaN             NaN
# 18160247               NaN                          NaN             NaN
# 18160248               NaN                          NaN             NaN
# 18160249               NaN                          NaN             NaN
# 18160250               NaN                          NaN             NaN
# 18160251               NaN                          NaN             NaN
# 18160252               NaN                          NaN             NaN
# 18160253               NaN                          NaN             NaN
# 18160254               NaN                          NaN             NaN
# 18160255               NaN                          NaN             NaN
# 18160256               NaN                          NaN             NaN
# 18160257               NaN                          NaN             NaN
# 18160258               NaN                          NaN             NaN
# 18160259               NaN                          NaN             NaN
# 18160260               NaN                          NaN             NaN
# 18160261               NaN                          NaN             NaN
# 18160262               NaN                          NaN             NaN
# 18160263               NaN                          NaN             NaN
# 18160264               NaN                          NaN             NaN
#
#          neighbourhood_cleansed neighbourhood_group_cleansed      city ...  \
# 0                Hell's Kitchen                    Manhattan  New York ...
# 1                Hell's Kitchen                    Manhattan  New York ...
# 2                Hell's Kitchen                    Manhattan  New York ...
# 3                Hell's Kitchen                    Manhattan  New York ...
# 4                Hell's Kitchen                    Manhattan  New York ...
# 5                Hell's Kitchen                    Manhattan  New York ...
# 6                Hell's Kitchen                    Manhattan  New York ...
# 7                Hell's Kitchen                    Manhattan  New York ...
# 8                Hell's Kitchen                    Manhattan  New York ...
# 9                Hell's Kitchen                    Manhattan  New York ...
# 10               Hell's Kitchen                    Manhattan  New York ...
# 11               Hell's Kitchen                    Manhattan  New York ...
# 12               Hell's Kitchen                    Manhattan  New York ...
# 13               Hell's Kitchen                    Manhattan  New York ...
# 14               Hell's Kitchen                    Manhattan  New York ...
# 15               Hell's Kitchen                    Manhattan  New York ...
# 16               Hell's Kitchen                    Manhattan  New York ...
# 17               Hell's Kitchen                    Manhattan  New York ...
# 18               Hell's Kitchen                    Manhattan  New York ...
# 19               Hell's Kitchen                    Manhattan  New York ...
# 20               Hell's Kitchen                    Manhattan  New York ...
# 21               Hell's Kitchen                    Manhattan  New York ...
# 22               Hell's Kitchen                    Manhattan  New York ...
# 23               Hell's Kitchen                    Manhattan  New York ...
# 24               Hell's Kitchen                    Manhattan  New York ...
# 25               Hell's Kitchen                    Manhattan  New York ...
# 26               Hell's Kitchen                    Manhattan  New York ...
# 27               Hell's Kitchen                    Manhattan  New York ...
# 28               Hell's Kitchen                    Manhattan  New York ...
# 29               Hell's Kitchen                    Manhattan  New York ...
# ...                         ...                          ...       ... ...
# 18160235                    NaN                          NaN       NaN ...
# 18160236                    NaN                          NaN       NaN ...
# 18160237                    NaN                          NaN       NaN ...
# 18160238                    NaN                          NaN       NaN ...
# 18160239                    NaN                          NaN       NaN ...
# 18160240                    NaN                          NaN       NaN ...
# 18160241                    NaN                          NaN       NaN ...
# 18160242                    NaN                          NaN       NaN ...
# 18160243                    NaN                          NaN       NaN ...
# 18160244                    NaN                          NaN       NaN ...
# 18160245                    NaN                          NaN       NaN ...
# 18160246                    NaN                          NaN       NaN ...
# 18160247                    NaN                          NaN       NaN ...
# 18160248                    NaN                          NaN       NaN ...
# 18160249                    NaN                          NaN       NaN ...
# 18160250                    NaN                          NaN       NaN ...
# 18160251                    NaN                          NaN       NaN ...
# 18160252                    NaN                          NaN       NaN ...
# 18160253                    NaN                          NaN       NaN ...
# 18160254                    NaN                          NaN       NaN ...
# 18160255                    NaN                          NaN       NaN ...
# 18160256                    NaN                          NaN       NaN ...
# 18160257                    NaN                          NaN       NaN ...
# 18160258                    NaN                          NaN       NaN ...
# 18160259                    NaN                          NaN       NaN ...
# 18160260                    NaN                          NaN       NaN ...
# 18160261                    NaN                          NaN       NaN ...
# 18160262                    NaN                          NaN       NaN ...
# 18160263                    NaN                          NaN       NaN ...
# 18160264                    NaN                          NaN       NaN ...
#
#          require_guest_phone_verification reviews_per_month        date  \
# 0                                       t              1.87  2019-03-06
# 1                                       t              1.87  2019-03-07
# 2                                       t              1.87  2019-03-08
# 10               f   185.0              2.0            1125.0  2019    03  16
# 11               t   185.0              2.0            1125.0  2019    03  17
# 12               f   185.0              2.0            1125.0  2019    03  18
# 13               f   185.0              2.0            1125.0  2019    03  19
# 14               f   185.0              2.0            1125.0  2019    03  20
# 15               f   185.0              2.0            1125.0  2019    03  21
# 16               t   185.0              2.0            1125.0  2019    03  22
# 17               t   185.0              2.0            1125.0  2019    03  23
# 18               t   185.0              2.0            1125.0  2019    03  24
# 19               f   185.0              2.0            1125.0  2019    03  25
# 20               f   185.0              2.0            1125.0  2019    03  26
# 21               f   185.0              2.0            1125.0  2019    03  27
# 22               f   185.0              2.0            1125.0  2019    03  28
# 23               t   185.0              2.0            1125.0  2019    03  29
# 24               t   185.0              2.0            1125.0  2019    03  30
# 25               t   185.0              2.0            1125.0  2019    03  31
# 26               f   185.0              2.0            1125.0  2019    04  01
# 27               f   185.0              2.0            1125.0  2019    04  02
# 28               f   185.0              2.0            1125.0  2019    04  03
# 29               f   185.0              2.0            1125.0  2019    04  04
# ...            ...     ...              ...               ...   ...   ...  ..
# 18160235         f   103.0              1.0               4.0  2020    02  05
# 18160236         f   103.0              1.0               4.0  2020    02  06
# 18160237         f   103.0              1.0               4.0  2020    02  07
# 18160238         f   103.0              1.0               4.0  2020    02  08
# 18160239         f   103.0              1.0               4.0  2020    02  09
# 18160240         f   103.0              1.0               4.0  2020    02  10
# 18160241         f   103.0              1.0               4.0  2020    02  11
# 18160242         f   103.0              1.0               4.0  2020    02  12
# 18160243         f   103.0              1.0               4.0  2020    02  13
# 18160244         f   103.0              1.0               4.0  2020    02  14
# 18160245         f   103.0              1.0               4.0  2020    02  15
# 18160246         f   103.0              1.0               4.0  2020    02  16
# 18160247         f   103.0              1.0               4.0  2020    02  17
# 18160248         f   103.0              1.0               4.0  2020    02  18
# 18160249         f   103.0              1.0               4.0  2020    02  19
# 18160250         f   103.0              1.0               4.0  2020    02  20
# 18160251         f   103.0              1.0               4.0  2020    02  21
# 18160252         f   103.0              1.0               4.0  2020    02  22
# 18160253         f   103.0              1.0               4.0  2020    02  23
# 18160254         f   103.0              1.0               4.0  2020    02  24
# 18160255         f   103.0              1.0               4.0  2020    02  25
# 18160256         f   103.0              1.0               4.0  2020    02  26
# 18160257         f   103.0              1.0               4.0  2020    02  27
# 18160258         f   103.0              1.0               4.0  2020    02  28
# 18160259         f   103.0              1.0               4.0  2020    02  29
# 18160260         f   103.0              1.0               4.0  2020    03  01
# 18160261         f   103.0              1.0               4.0  2020    03  02
# 18160262         f   103.0              1.0               4.0  2020    03  03
# 18160263         f   103.0              1.0               4.0  2020    03  04
# 18160264         f   103.0              1.0               4.0  2020    03  05
#
# [18160265 rows x 60 columns]

# %%
listings_calendar = listings_calendar.dropna()

# %%
listings_calendar
# Out:
#           listing_id experiences_offered    host_id  host_acceptance_rate  \
# 0            1742654                none  9173924.0                   0.0
# 1            1742654                none  9173924.0                   0.0
# 2            1742654                none  9173924.0                   0.0
# 5                Hell's Kitchen                    Manhattan  New York ...
# 6                Hell's Kitchen                    Manhattan  New York ...
# 7                Hell's Kitchen                    Manhattan  New York ...
# 8                Hell's Kitchen                    Manhattan  New York ...
# 9                Hell's Kitchen                    Manhattan  New York ...
# 10               Hell's Kitchen                    Manhattan  New York ...
# 11               Hell's Kitchen                    Manhattan  New York ...
# 12               Hell's Kitchen                    Manhattan  New York ...
# 13               Hell's Kitchen                    Manhattan  New York ...
# 14               Hell's Kitchen                    Manhattan  New York ...
# 15               Hell's Kitchen                    Manhattan  New York ...
# 16               Hell's Kitchen                    Manhattan  New York ...
# 17               Hell's Kitchen                    Manhattan  New York ...
# 18               Hell's Kitchen                    Manhattan  New York ...
# 19               Hell's Kitchen                    Manhattan  New York ...
# 20               Hell's Kitchen                    Manhattan  New York ...
# 21               Hell's Kitchen                    Manhattan  New York ...
# 22               Hell's Kitchen                    Manhattan  New York ...
# 23               Hell's Kitchen                    Manhattan  New York ...
# 24               Hell's Kitchen                    Manhattan  New York ...
# 25               Hell's Kitchen                    Manhattan  New York ...
# 26               Hell's Kitchen                    Manhattan  New York ...
# 27               Hell's Kitchen                    Manhattan  New York ...
# 28               Hell's Kitchen                    Manhattan  New York ...
# 29               Hell's Kitchen                    Manhattan  New York ...
# ...                         ...                          ...       ... ...
# 11376266         Hell's Kitchen                    Manhattan  New York ...
# 11376267         Hell's Kitchen                    Manhattan  New York ...
# 11376268         Hell's Kitchen                    Manhattan  New York ...
# 11376269         Hell's Kitchen                    Manhattan  New York ...
# 11376270         Hell's Kitchen                    Manhattan  New York ...
# 11376271         Hell's Kitchen                    Manhattan  New York ...
# 11376272         Hell's Kitchen                    Manhattan  New York ...
# 11376273         Hell's Kitchen                    Manhattan  New York ...
# 11376274         Hell's Kitchen                    Manhattan  New York ...
# 11376275         Hell's Kitchen                    Manhattan  New York ...
# 11376276         Hell's Kitchen                    Manhattan  New York ...
# 11376277         Hell's Kitchen                    Manhattan  New York ...
# 11376278         Hell's Kitchen                    Manhattan  New York ...
# 11376279         Hell's Kitchen                    Manhattan  New York ...
# 11376280         Hell's Kitchen                    Manhattan  New York ...
# 11376281         Hell's Kitchen                    Manhattan  New York ...
# 11376282         Hell's Kitchen                    Manhattan  New York ...
# 11376283         Hell's Kitchen                    Manhattan  New York ...
# 11376284         Hell's Kitchen                    Manhattan  New York ...
# 11376285         Hell's Kitchen                    Manhattan  New York ...
# 11376286         Hell's Kitchen                    Manhattan  New York ...
# 11376287         Hell's Kitchen                    Manhattan  New York ...
# 11376288         Hell's Kitchen                    Manhattan  New York ...
# 11376289         Hell's Kitchen                    Manhattan  New York ...
# 11376290         Hell's Kitchen                    Manhattan  New York ...
# 11376291         Hell's Kitchen                    Manhattan  New York ...
# 11376292         Hell's Kitchen                    Manhattan  New York ...
# 11376293         Hell's Kitchen                    Manhattan  New York ...
# 11376294         Hell's Kitchen                    Manhattan  New York ...
# 8                f   185.0              2.0            1125.0  2019    03  14
# 9                f   185.0              2.0            1125.0  2019    03  15
# 10               f   185.0              2.0            1125.0  2019    03  16
# 11               t   185.0              2.0            1125.0  2019    03  17
# 12               f   185.0              2.0            1125.0  2019    03  18
# 13               f   185.0              2.0            1125.0  2019    03  19
# 14               f   185.0              2.0            1125.0  2019    03  20
# 15               f   185.0              2.0            1125.0  2019    03  21
# 16               t   185.0              2.0            1125.0  2019    03  22
# 17               t   185.0              2.0            1125.0  2019    03  23
# 18               t   185.0              2.0            1125.0  2019    03  24
# 19               f   185.0              2.0            1125.0  2019    03  25
# 20               f   185.0              2.0            1125.0  2019    03  26
# 21               f   185.0              2.0            1125.0  2019    03  27
# 22               f   185.0              2.0            1125.0  2019    03  28
# 23               t   185.0              2.0            1125.0  2019    03  29
# 24               t   185.0              2.0            1125.0  2019    03  30
# 25               t   185.0              2.0            1125.0  2019    03  31
# 26               f   185.0              2.0            1125.0  2019    04  01
# 27               f   185.0              2.0            1125.0  2019    04  02
# 28               f   185.0              2.0            1125.0  2019    04  03
# 29               f   185.0              2.0            1125.0  2019    04  04
# ...            ...     ...              ...               ...   ...   ...  ..
# 11376266         t   145.0             30.0             365.0  2020    02  04
# 11376267         t   145.0             30.0             365.0  2020    02  05
# 11376268         t   145.0             30.0             365.0  2020    02  06
# 11376269         t   145.0             30.0             365.0  2020    02  07
# 11376270         t   145.0             30.0             365.0  2020    02  08
# 11376271         t   145.0             30.0             365.0  2020    02  09
# 11376272         t   145.0             30.0             365.0  2020    02  10
# 11376273         t   145.0             30.0             365.0  2020    02  11
# 11376274         t   145.0             30.0             365.0  2020    02  12
# 11376275         t   145.0             30.0             365.0  2020    02  13
# 11376276         t   145.0             30.0             365.0  2020    02  14
# 11376277         t   145.0             30.0             365.0  2020    02  15
# 11376278         t   145.0             30.0             365.0  2020    02  16
# 11376279         t   145.0             30.0             365.0  2020    02  17
# 11376280         t   145.0             30.0             365.0  2020    02  18
# 11376281         t   145.0             30.0             365.0  2020    02  19
# 11376282         t   145.0             30.0             365.0  2020    02  20
# 11376283         t   145.0             30.0             365.0  2020    02  21
# 11376284         t   145.0             30.0             365.0  2020    02  22
# 11376285         t   145.0             30.0             365.0  2020    02  23
# 11376286         t   145.0             30.0             365.0  2020    02  24
# 11376287         t   145.0             30.0             365.0  2020    02  25
# 11376288         t   145.0             30.0             365.0  2020    02  26
# 11376289         t   145.0             30.0             365.0  2020    02  27
# 11376290         t   145.0             30.0             365.0  2020    02  28
# 11376291         t   145.0             30.0             365.0  2020    02  29
# 11376292         t   145.0             30.0             365.0  2020    03  01
# 11376293         t   145.0             30.0             365.0  2020    03  02
# 11376294         t   145.0             30.0             365.0  2020    03  03
# 11376295         t   145.0             30.0             365.0  2020    03  04
#
# [11374115 rows x 60 columns]

# %%
listings.to_csv("clean_listings.csv")

# %%
calendar.to_csv("clean_calendar.csv")

# %%
listings_calendar.to_csv('listings_calendar.csv')
